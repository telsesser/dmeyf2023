# %% [markdown]
# # Crear Target
#
# ## Ejercicio 1:
# Cree el archivo `competencia_01.csv`, usando el `competencia_01_crudo.csv` con una variable adicional llamada `clase_ternaria`, que contenga las categorías **CONTINUA**, **BAJA+1** y **BAJA+2**
#
# ### Ayudita
#
# Para practicar el muy útil y necesario lenguaje **SQL**, vamos a utilizar una base de datos **OLAP** llamada **DuckDB**.
#
# La documentación la puede encontrar [aquí](https://duckdb.org/docs/archive/0.8.1/sql/introduction)
# Procedemos a instalarla, esto se debe ejecutar una sola vez

# %%
# %%bash
# pip install duckdb
# pip install jupysql
# pip install duckdb-engine
# pip install pandas
# Out:
# Requirement already satisfied: duckdb in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (0.8.1)
# Requirement already satisfied: jupysql in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: prettytable in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from jupysql) (3.8.0)
# Requirement already satisfied: ipython in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from jupysql) (8.14.0)
# Requirement already satisfied: sqlalchemy in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from jupysql) (2.0.20)
# Requirement already satisfied: sqlparse in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from jupysql) (0.4.4)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: sqlglot in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from jupysql) (17.14.2)
# Requirement already satisfied: jinja2 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from jupysql) (3.1.2)
# Requirement already satisfied: ploomber-core>=0.2.7 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from jupysql) (0.2.14)
# Requirement already satisfied: click in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ploomber-core>=0.2.7->jupysql) (8.1.7)
# Requirement already satisfied: pyyaml in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.1)
# Requirement already satisfied: posthog in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ploomber-core>=0.2.7->jupysql) (3.0.2)
# Requirement already satisfied: backcall in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ipython->jupysql) (0.2.0)
# Requirement already satisfied: decorator in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ipython->jupysql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ipython->jupysql) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ipython->jupysql) (0.1.6)
# Requirement already satisfied: pickleshare in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ipython->jupysql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ipython->jupysql) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ipython->jupysql) (2.16.1)
# Requirement already satisfied: stack-data in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ipython->jupysql) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ipython->jupysql) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from ipython->jupysql) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from jinja2->jupysql) (2.1.3)
# Requirement already satisfied: wcwidth in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from prettytable->jupysql) (0.2.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from sqlalchemy->jupysql) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from sqlalchemy->jupysql) (2.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython->jupysql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython->jupysql) (0.7.0)
# Requirement already satisfied: requests<3.0,>=2.7 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.31.0)
# Requirement already satisfied: six>=1.5 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.8.2)
# Requirement already satisfied: executing>=1.2.0 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from stack-data->ipython->jupysql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from stack-data->ipython->jupysql) (2.2.1)
# Requirement already satisfied: pure-eval in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from stack-data->ipython->jupysql) (0.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2023.7.22)
# Requirement already satisfied: duckdb-engine in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (0.9.2)
# Requirement already satisfied: duckdb>=0.4.0 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from duckdb-engine) (0.8.1)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from duckdb-engine) (2.0.20)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from sqlalchemy>=1.3.22->duckdb-engine) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from sqlalchemy>=1.3.22->duckdb-engine) (2.0.2)
# Requirement already satisfied: pandas in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /home/tomi/Escritorio/Maestria/2 - DMEyF/dmeyf2023/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# Configuramos el entorno de ejecución. Si ya tiene todo instalado, solo necesita ejecutar esta celda para empezar a usar **duckdb**

# %%
import duckdb
import pandas as pd

# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:default:
# Out:
# There's a new jupysql version available (0.10.1), you're running 0.10.0. To upgrade: pip install jupysql --upgrade

# %% [markdown]
# Y ya podemos usar **SQL** dentro de una notebook!

# %%
# %%sql
# select 'hola mundo'
# Out:
#   'hola mundo'
# 0   hola mundo

# %% [markdown]
# Para cargar el archivo `.csv` a una tabla:

# %%
# %%sql
# create or replace table competencia_01 as
# select
#     *
# from read_csv_auto('/home/tomi/Escritorio/Maestria/2 - DMEyF/datasets/competencia_01_crudo.csv')
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT COUNT(*) AS total_filas
# FROM competencia_01;
# Out:
#    total_filas
# 0       491063

# %% [markdown]
# Hagamos unas queries básicas para comprobar que todo esta funcionando bien.

# %%
# %sql select highest_foto_mes from competencia_01
# Out:
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (duckdb.BinderException) Binder Error: Referenced column "highest_foto_mes" not found in FROM clause!
# Candidate bindings: "competencia_01.foto_mes"
# LINE 1: select highest_foto_mes from competencia_01
#                ^
# [SQL: select highest_foto_mes from competencia_01]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# %sql select * from competencia_01 limit 5
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0           29183981    202103               1            0         0
# 1           29184630    202103               1            0         0
# 2           29185433    202103               1            0         0
# 3           29185587    202103               1            0         0
# 4           29185646    202103               1            0         0
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            50                 197       14468.81             125765.29
# 1            59                 322       11901.57              74158.93
# 2            68                 268         847.15              21672.47
# 3            79                 322        4976.94              47735.98
# 4            60                 257        2860.45              37800.71
#
#    mcomisiones  ...  Visa_madelantodolares  Visa_fultimo_cierre  Visa_mpagado  \
# 0      2389.82  ...                    0.0                    7          0.00
# 1     18750.68  ...                    0.0                    1          0.00
# 2       481.62  ...                    0.0                   21       4692.00
# 3      1839.31  ...                    0.0                    1          0.00
# 4      4035.40  ...                    0.0                   21     380616.14
#
#    Visa_mpagospesos  Visa_mpagosdolares  Visa_fechaalta  Visa_mconsumototal  \
# 0        -114954.00                0.00            5938           101050.66
# 1         -40330.15               17.59            4089            26834.09
# 2          -1173.00                0.00            7829             1651.36
# 3         -15988.67                0.00            7580            30025.29
# 4         -97383.25                0.00            7827           359610.70
#
#    Visa_cconsumos  Visa_cadelantosefectivo  Visa_mpagominimo
# 0              68                        0          71811.06
# 1               7                        0           3894.36
# 2               3                        0           1560.09
# 3              11                        0           1700.85
# 4              31                        0          15600.90
#
# [5 rows x 154 columns]

# %%
# %%sql
# select
#     foto_mes
#     , count(*) as cantidad
# from competencia_01
# group by foto_mes
# Out:
#    foto_mes  cantidad
# 0    202103    163324
# 1    202104    163637
# 2    202105    164102

# %%
# %%sql
# create or replace table meses AS
# SELECT DISTINCT foto_mes
# FROM competencia_01;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %sql select * from meses
# Out:
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (duckdb.CatalogException) Catalog Error: Table with name meses does not exist!
# Did you mean "temp.information_schema.tables"?
# LINE 1: select * from meses
#                       ^
# [SQL: select * from meses]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %%
# %%sql
# CREATE TEMPORARY TABLE consulta_sql AS
# SELECT 'SELECT cliente_id, ' ||
#        LISTAGG('MAX(CASE WHEN mes = ''' || mes || ''' THEN 1 ELSE 0 END) AS ' || mes, ', ')
#        WITHIN GROUP (ORDER BY mes) ||
#        ' FROM tu_tabla_original GROUP BY cliente_id;' AS sql
# FROM meses_disponibles;
# Out:
# RuntimeError: (duckdb.ParserException) Parser Error: Unknown ordered aggregate "LISTAGG".
# [SQL: CREATE TEMPORARY TABLE consulta_sql AS
# SELECT 'SELECT cliente_id, ' ||
#        LISTAGG('MAX(CASE WHEN mes = ''' || mes || ''' THEN 1 ELSE 0 END) AS ' || mes, ', ')
#        WITHIN GROUP (ORDER BY mes) ||
#        ' FROM tu_tabla_original GROUP BY cliente_id;' AS sql
# FROM meses_disponibles;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# If you need help solving this issue, send us a message: https://ploomber.io/community

# %% [markdown]
# Perfecto, ahora cree una nueva tabla con la variable adicional que se le pide. Algunas funciones que le pueden ser útiles:  [where](https://duckdb.org/docs/sql/query_syntax/where), [left join](https://duckdb.org/docs/sql/query_syntax/from), [case statement](https://duckdb.org/docs/sql/expressions/case)

# %%
# %%sql
# SELECT
#     numero_de_cliente,
#     MAX(CASE WHEN foto_mes = 202103 THEN 1 ELSE 0 END) AS Enero,
#     MAX(CASE WHEN foto_mes = 202104 THEN 1 ELSE 0 END) AS Febrero,
#     MAX(CASE WHEN foto_mes = 202105 THEN 1 ELSE 0 END) AS Marzo,
#     -- Repite esto para los demás meses.
# FROM
#     competencia_01
# GROUP BY
#     numero_de_cliente;
# Out:
#         numero_de_cliente  Enero  Febrero  Marzo
# 0                29185646      1        1      1
# 1                29188883      1        1      1
# 2                29198669      1        1      1
# 3                29202529      1        1      1
# 4                29205501      1        1      1
# ...                   ...    ...      ...    ...
# 166115           54175890      0        0      1
# 166116           58674153      0        0      1
# 166117           57137632      0        0      1
# 166118           60030971      0        0      1
# 166119           60237214      0        0      1
#
# [166120 rows x 4 columns]

# %%
# %%sql
# SELECT
#     numero_de_cliente,
#     LIST(((foto_mes//100-2021)*12+foto_mes%100) order by foto_mes asc) as mes,
# FROM
#     competencia_01
# GROUP BY
#     numero_de_cliente;
# Out:
#         numero_de_cliente        mes
# 0                29185646  [3, 4, 5]
# 1                29188883  [3, 4, 5]
# 2                29198669  [3, 4, 5]
# 3                29202529  [3, 4, 5]
# 4                29205501  [3, 4, 5]
# ...                   ...        ...
# 166115           54175890        [5]
# 166116           58674153        [5]
# 166117           57137632        [5]
# 166118           60030971        [5]
# 166119           60237214        [5]
#
# [166120 rows x 2 columns]

# %%
# %%sql
# SELECT numero_de_cliente,foto_mes
# FROM competencia_01
# ORDER BY numero_de_cliente, foto_mes;
# Out:
#         numero_de_cliente  foto_mes
# 0                29183981    202103
# 1                29183981    202104
# 2                29183981    202105
# 3                29184630    202103
# 4                29184630    202104
# ...                   ...       ...
# 491058          186790659    202105
# 491059          186792315    202105
# 491060          186795526    202105
# 491061          186798379    202105
# 491062          186836338    202105
#
# [491063 rows x 2 columns]

# %%
# %%sql
# ROLLBACK
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# create or replace table proceso AS
# SELECT numero_de_cliente,foto_mes,meses_futuro_activo,
# CASE WHEN meses_futuro_activo > 2 THEN 'CONTINUA'
#     ELSE ('BAJA+' || meses_futuro_activo)
#     END as clase_ternaria
# FROM(
#     SELECT numero_de_cliente,foto_mes,
#     SUM(aux) OVER (
#         PARTITION BY "numero_de_cliente"
#         ORDER BY numero_de_cliente, foto_mes
#         ROWS BETWEEN 0 PRECEDING
#             AND 2 FOLLOWING) AS meses_futuro_activo
#     FROM
#         (SELECT
#             numero_de_cliente,
#             foto_mes,
#             CASE
#                 WHEN foto_mes = 202105 THEN 3
#                 WHEN foto_mes = 202104 THEN 2
#                 ELSE 1 END AS aux
#         FROM competencia_01
#         ORDER BY numero_de_cliente, foto_mes)
#     ORDER BY numero_de_cliente, foto_mes
# );
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT numero_de_cliente,foto_mes,meses_futuro_activo,
# CASE WHEN meses_futuro_activo > 2 THEN 'CONTINUA'
#     ELSE ('BAJA+' || meses_futuro_activo)
#     END as clase_ternaria
# FROM(
#     SELECT numero_de_cliente,foto_mes,
#     SUM(aux) OVER (
#         PARTITION BY "numero_de_cliente"
#         ORDER BY numero_de_cliente, foto_mes
#         ROWS BETWEEN 0 PRECEDING
#             AND 2 FOLLOWING) AS meses_futuro_activo
#     FROM
#         (SELECT
#             numero_de_cliente,
#             foto_mes,
#             (foto_mes//100-2021)*12+foto_mes%100 as mes
#         FROM competencia_01
#         ORDER BY numero_de_cliente, foto_mes)
#     ORDER BY numero_de_cliente, foto_mes
# );
# Out:
#         numero_de_cliente  foto_mes  meses_futuro_activo clase_ternaria
# 0                29183981    202103                  6.0       CONTINUA
# 1                29183981    202104                  5.0       CONTINUA
# 2                29183981    202105                  3.0       CONTINUA
# 3                29184630    202103                  6.0       CONTINUA
# 4                29184630    202104                  5.0       CONTINUA
# ...                   ...       ...                  ...            ...
# 491058          186790659    202105                  3.0       CONTINUA
# 491059          186792315    202105                  3.0       CONTINUA
# 491060          186795526    202105                  3.0       CONTINUA
# 491061          186798379    202105                  3.0       CONTINUA
# 491062          186836338    202105                  3.0       CONTINUA
#
# [491063 rows x 4 columns]

# %%
# %%sql
#     SELECT numero_de_cliente,foto_mes,mes,
#     lead(mes,1,-1) OVER (PARTITION BY "numero_de_cliente" ORDER BY numero_de_cliente, mes) AS 'mes+1',
#     lead(mes,2,-1) OVER (PARTITION BY "numero_de_cliente" ORDER BY numero_de_cliente, mes) AS 'mes+2',
#     FROM
#         (SELECT
#             numero_de_cliente,
#             foto_mes,
#             (foto_mes//100-2021)*12+foto_mes%100 as mes
#         FROM competencia_01
#         ORDER BY numero_de_cliente, foto_mes)
#     ORDER BY numero_de_cliente, foto_mes;
# Out:
#         numero_de_cliente  foto_mes  mes  mes+1  mes+2
# 0                29183981    202103    3      4      5
# 1                29183981    202104    4      5     -1
# 2                29183981    202105    5     -1     -1
# 3                29184630    202103    3      4      5
# 4                29184630    202104    4      5     -1
# ...                   ...       ...  ...    ...    ...
# 491058          186790659    202105    5     -1     -1
# 491059          186792315    202105    5     -1     -1
# 491060          186795526    202105    5     -1     -1
# 491061          186798379    202105    5     -1     -1
# 491062          186836338    202105    5     -1     -1
#
# [491063 rows x 5 columns]

# %%
# %%sql
# ROLLBACK
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# create or replace table proceso AS
# SELECT *,
# CASE
#     -- Condiciones de borde:
#     WHEN ("mes+1"=0) THEN 'CONTINUA'
#     WHEN ("mes+2"=0) THEN 'CONTINUA'
#     -- Si mes siguiente no es consecutivo o no existe:
#     WHEN ("mes"+1 != "mes+1") THEN 'BAJA+1'
#     WHEN ("mes"+2 != "mes+2") THEN 'BAJA+2'
#     -- si proximos 2 meses consecutivos activos:
#     ELSE 'CONTINUA' END AS "clase_ternaria"
# FROM (
#     SELECT *,
#     IF(foto_mes = 202105, 0, lead(mes,1,-1) OVER (PARTITION BY "numero_de_cliente" ORDER BY numero_de_cliente, mes)) AS 'mes+1',
#     IF(foto_mes = 202105 OR foto_mes = 202104, 0,lead(mes,2,-1) OVER (PARTITION BY "numero_de_cliente" ORDER BY numero_de_cliente, mes)) AS 'mes+2',
#     FROM
#         (SELECT
#             *,
#             (foto_mes//100-2021)*12+foto_mes%100 as mes
#         FROM competencia_01
#         ORDER BY numero_de_cliente, foto_mes)
#     ORDER BY numero_de_cliente, foto_mes);
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# select
#     foto_mes,
#     clase_ternaria,
#     count(*) as cantidad
# from proceso
# group by foto_mes,clase_ternaria
# Out:
#    foto_mes clase_ternaria  cantidad
# 0    202103       CONTINUA    161311
# 1    202104       CONTINUA    163637
# 2    202105       CONTINUA    164102
# 3    202103         BAJA+1      1050
# 4    202103         BAJA+2       963

# %%
# %%sql
# ALTER TABLE proceso
# DROP COLUMN "mes+2";
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# ## Ejercicio 1.1
#
# * ¿Cuál es la nominalidad de cada clase?
# * ¿Cuál es la proporción del target?

# %%
# %%sql
# -- introduzca sus queries

# %% [markdown]
# Para guardar a un **.csv** simplemente debe ejecutar la siguiente sentencia

# %%
# %%sql
# COPY proceso TO '/home/tomi/Escritorio/Maestria/2 - DMEyF/datasets/competencia_01.csv' (FORMAT CSV, HEADER)
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# ## Ejercicio 2 - Avanzado
# Use ahora el archivo `ejercicio_target.csv` y calcule para todos los clientes en todos los periodos su **clase_ternaria** al mismo tiempo

# %%
# %%sql
# create or replace table competencia_01 as
# select
#     *
# from read_csv_auto('/home/tomi/Escritorio/Maestria/2 - DMEyF/datasets/ejercicio_target.csv')
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %sql select * from competencia_01 limit 5
# Out:
#    periodo                    nombre
# 0   202110            Isaac Valverde
# 1   202110  Santiago Córdova Tercero
# 2   202110           Jerónimo Ocasio
# 3   202110      Isabel Terrazas Hijo
# 4   202110           Diego Caballero

# %%
# %sql select max(periodo) from competencia_01 limit 5

# %%
# %%sql
#
# SELECT nombre,periodo,meses_futuro_activo,
# CASE WHEN meses_futuro_activo > 2 THEN 'CONTINUA'
#     ELSE ('BAJA+' || meses_futuro_activo)
#     END as clase_ternaria
# FROM(
#     SELECT nombre,periodo,
#     SUM(aux) OVER (
#         PARTITION BY "nombre"
#         ORDER BY nombre, periodo
#         ROWS BETWEEN 0 PRECEDING
#             AND 2 FOLLOWING) AS meses_futuro_activo
#     FROM
#         (SELECT
#             nombre,
#             periodo,
#             CASE
#                 WHEN periodo = 202203 THEN 3
#                 WHEN periodo = 202202 THEN 2
#                 ELSE 1 END AS aux
#         FROM competencia_01
#         ORDER BY nombre, periodo)
#     ORDER BY nombre, periodo
# );
# Out:
#                   nombre  periodo  meses_futuro_activo clase_ternaria
# 0          Aarón Pantoja   202201                  6.0       CONTINUA
# 1          Aarón Pantoja   202202                  5.0       CONTINUA
# 2          Aarón Pantoja   202203                  3.0       CONTINUA
# 3         Abril Palomino   202201                  6.0       CONTINUA
# 4         Abril Palomino   202202                  5.0       CONTINUA
# ..                   ...      ...                  ...            ...
# 734  Ximena Rael Segundo   202111                  3.0       CONTINUA
# 735  Ximena Rael Segundo   202112                  4.0       CONTINUA
# 736  Ximena Rael Segundo   202201                  6.0       CONTINUA
# 737  Ximena Rael Segundo   202202                  5.0       CONTINUA
# 738  Ximena Rael Segundo   202203                  3.0       CONTINUA
#
# [739 rows x 4 columns]

# %%
# %%sql
# select
#     clase_ternaria
#     , count(*) as cantidad
# from proceso
# group by clase_ternaria
# Out:
#   clase_ternaria  cantidad
# 0       CONTINUA       674
# 1         BAJA+1        36
# 2         BAJA+2        29
